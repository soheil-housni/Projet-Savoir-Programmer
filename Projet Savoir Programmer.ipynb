# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data=pd.read_csv("Impact_of_Remote_Work_on_Mental_Health.csv")

display(data)

print(data.columns)
print(data["Gender"].unique())
print(data["Industry"].unique())
print(data["Work_Life_Balance_Rating"].unique())
print(data["Mental_Health_Condition"].unique())
print(data["Stress_Level"].unique())
print(data["Productivity_Change"].unique())
print(data["Social_Isolation_Rating"].unique())
print(data["Satisfaction_with_Remote_Work"].unique())
print(data["Company_Support_for_Remote_Work"].unique())
print(data["Physical_Activity"].unique())
print(data["Sleep_Quality"].unique())
print(data["Region"].unique())
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-binary                 HR  Healthcare
# 1        EMP0002   40      Female     Data Scientist          IT
# 2        EMP0003   59  Non-binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %%
mental_healt_propotions=data["Mental_Health_Condition"].value_counts(normalize=True, dropna=False)
#display(mental_healt_propotions)


work_location=data.groupby(["Work_Location"])
mental_health_per_work_location=work_location["Mental_Health_Condition"].value_counts(normalize=True, dropna=False)
#display(mental_health_per_work_location)

industry=data.groupby(["Industry"])
mental_health_per_industry=industry["Mental_Health_Condition"].value_counts(normalize=True, dropna=False)
#display(mental_health_per_industry)

region=data.groupby(["Region"])
mental_health_per_region=region["Mental_Health_Condition"].value_counts(dropna=False)
#display(mental_health_per_region)
remote_work_per_region=region["Work_Location"].value_counts(dropna=False)
#display(remote_work_per_region)

df=data[data['Work_Location']=="Remote"].groupby(["Industry"])
result=df["Mental_Health_Condition"].value_counts(normalize=True, dropna=False)
display(result)
# Out:
# Industry       Mental_Health_Condition
# Consulting     Anxiety                    0.320000
#                NaN                        0.235556
#                Depression                 0.226667
#                Burnout                    0.217778
# Education      NaN                        0.277311
#                Anxiety                    0.247899
#                Depression                 0.243697
#                Burnout                    0.231092
# Finance        NaN                        0.303502
#                Burnout                    0.295720
#                Anxiety                    0.217899
#                Depression                 0.182879
# Healthcare     Burnout                    0.289683
#                Depression                 0.265873
#                NaN                        0.257937
#                Anxiety                    0.186508
# IT             Anxiety                    0.280335
#                Depression                 0.276151
# ...

# %%
df=data[data['Work_Location']=="Onsite"].groupby(["Industry"])
result=df["Mental_Health_Condition"].value_counts(normalize=True, dropna=False)
display(result)
# Out:
# Industry       Mental_Health_Condition
# Consulting     Depression                 0.277056
#                Burnout                    0.255411
#                Anxiety                    0.238095
#                NaN                        0.229437
# Education      Burnout                    0.266667
#                Depression                 0.258333
#                NaN                        0.241667
#                Anxiety                    0.233333
# Finance        Depression                 0.298701
#                Anxiety                    0.264069
#                Burnout                    0.242424
#                NaN                        0.194805
# Healthcare     Burnout                    0.275109
#                Depression                 0.266376
#                Anxiety                    0.231441
#                NaN                        0.227074
# IT             Burnout                    0.298039
#                Anxiety                    0.270588
# ...
